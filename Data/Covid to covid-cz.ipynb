# %%
import pandas as pd

# %%
covid_df = pd.read_csv("Covid-data.csv")

# %%
covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 71906      ZWE    Africa     Zimbabwe  2021-02-24      35960.0       50.0
# 71907      ZWE    Africa     Zimbabwe  2021-02-25      35994.0       34.0
# 71908      ZWE    Africa     Zimbabwe  2021-02-26      36044.0       50.0
# 71909      ZWE    Africa     Zimbabwe  2021-02-27      36058.0       14.0
# 71910      ZWE    Africa     Zimbabwe  2021-02-28      36089.0       31.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
covid_cz = covid_df[covid_df["location"]=="Czechia"]

# %%
covid_cz
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 16864      CZE    Europe  Czechia  2020-02-02          NaN        NaN
# 16865      CZE    Europe  Czechia  2020-02-09          NaN        NaN
# 16866      CZE    Europe  Czechia  2020-02-16          NaN        NaN
# 16867      CZE    Europe  Czechia  2020-02-23          NaN        NaN
# 16868      CZE    Europe  Czechia  2020-03-01          3.0        3.0
# ...        ...       ...      ...         ...          ...        ...
# 17228      CZE    Europe  Czechia  2021-02-24    1184352.0    15861.0
# 17229      CZE    Europe  Czechia  2021-02-25    1198168.0    13816.0
# 17230      CZE    Europe  Czechia  2021-02-26    1212780.0    14612.0
# 17231      CZE    Europe  Czechia  2021-02-27    1227595.0    14815.0
# 17232      CZE    Europe  Czechia  2021-02-28    1235480.0     7885.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
covid_cz.to_csv("covid_cz_full", index=None)

# %%
covid_cz = pd.read_csv("covid_cz_full")

# %%
covid_cz
# Out:
#     iso_code continent location        date  total_cases  new_cases  \
# 0        CZE    Europe  Czechia  2020-02-02          NaN        NaN
# 1        CZE    Europe  Czechia  2020-02-09          NaN        NaN
# 2        CZE    Europe  Czechia  2020-02-16          NaN        NaN
# 3        CZE    Europe  Czechia  2020-02-23          NaN        NaN
# 4        CZE    Europe  Czechia  2020-03-01          3.0        3.0
# ..       ...       ...      ...         ...          ...        ...
# 364      CZE    Europe  Czechia  2021-02-24    1184352.0    15861.0
# 365      CZE    Europe  Czechia  2021-02-25    1198168.0    13816.0
# 366      CZE    Europe  Czechia  2021-02-26    1212780.0    14612.0
# 367      CZE    Europe  Czechia  2021-02-27    1227595.0    14815.0
# 368      CZE    Europe  Czechia  2021-02-28    1235480.0     7885.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
covid_cz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               369 non-null    object
#  1   continent                              369 non-null    object
#  2   location                               369 non-null    object
#  3   date                                   369 non-null    object
#  4   total_cases                            365 non-null    float64
#  5   new_cases                              365 non-null    float64
#  6   new_cases_smoothed                     360 non-null    float64
#  7   total_deaths                           344 non-null    float64
#  8   new_deaths                             344 non-null    float64
#  9   new_deaths_smoothed                    360 non-null    float64
# ...

# %%
covid_cz = covid_cz[["date", "new_cases", "new_deaths", "new_tests", "new_vaccinations"]]

# %%
covid_cz
# Out:
#            date  new_cases  new_deaths  new_tests  new_vaccinations
# 0    2020-02-02        NaN         NaN        NaN               NaN
# 1    2020-02-09        NaN         NaN        NaN               NaN
# 2    2020-02-16        NaN         NaN        NaN               NaN
# 3    2020-02-23        NaN         NaN        NaN               NaN
# 4    2020-03-01        3.0         NaN        NaN               NaN
# ..          ...        ...         ...        ...               ...
# 364  2021-02-24    15861.0       145.0    91299.0           19207.0
# 365  2021-02-25    13816.0       153.0    85033.0           22224.0
# 366  2021-02-26    14612.0       164.0        NaN           19039.0
# 367  2021-02-27    14815.0       195.0        NaN            3313.0
# 368  2021-02-28     7885.0       145.0        NaN            2608.0
#
# [369 rows x 5 columns]

# %%
covid_cz.at["date", "2020-06-20"] = -148
# Out:
# /home/adam/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.loc[index, col] = value

# %%
covid_cz.to_csv("covid_cz", index=None)
